# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_excel('aprov_alunos.xlsx')

# %%
df.describe()
# Out:
#         ano_2015   ano_2016
# count  27.000000  27.000000
# mean   79.333333  80.185185
# std     4.969136   4.820126
# min    68.000000  70.000000
# 25%    76.000000  76.500000
# 50%    80.000000  81.000000
# 75%    81.500000  82.500000
# max    89.000000  91.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ano_2015  27 non-null     int64
#  1   ano_2016  27 non-null     int64
# dtypes: int64(2)
# memory usage: 564.0 bytes

# %%
scaler = MinMaxScaler()

dfn = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
dfn.head()
# Out:
#    ano_2015  ano_2016
# 0  0.428571  0.714286
# 1  0.523810  0.523810
# 2  0.714286  0.714286
# 3  0.619048  0.571429
# 4  0.238095  0.285714

# %%
x = df[['ano_2015']]
y = df[['ano_2016']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=42)
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
sqr = lr.score(x_train, y_train)
sqr
# Out:
# 0.8573811509591327

# %%
y_pred_test = lr.predict(x_test)
print('MSE:', metrics.mean_squared_error(y_test, y_pred_test))
print('MAE:', metrics.mean_absolute_error(y_test, y_pred_test))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_test)))
# Out:
# MSE: 7.65398891007387
# MAE: 1.820127884348068
# RMSE: 2.766584339953125

# %%
y_pred_train = lr.predict(x_train)
print('MSE:', metrics.mean_squared_error(y_train, y_pred_train))
print('MAE:', metrics.mean_absolute_error(y_train, y_pred_train))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_train, y_pred_train)))
# Out:
# MSE: 3.1675470299323476
# MAE: 1.3490872022982106
# RMSE: 1.7797603855385555
